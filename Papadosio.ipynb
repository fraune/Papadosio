# %% [markdown]
# # Get album list as CSV

# %% [markdown]
# ## Download raw HTML

# %%
ALBUM_LIST_URL = 'https://papadosio.bandcamp.com/music'

# %%
import requests

# Send a GET request to the URL
response = requests.get(ALBUM_LIST_URL)

# Check if the request was successful
if response.status_code == 200:
    # Get the HTML content of the page
    html_content = response.text

    # The file where you want to save the HTML content
    file_path = 'papadosio_bandcamp_music.html'

    # Write the HTML content to a file
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(html_content)

    print(f'HTML content saved to {file_path}')
else:
    print('Failed to retrieve the HTML content. Status Code:', response.status_code)
# Out:
# HTML content saved to papadosio_bandcamp_music.html

# %% [markdown]
# ## Parse HTML into CSV

# %%
# Base URL to prepend to album and track URLs
BASE_URL = 'https://papadosio.bandcamp.com'

# %%
from bs4 import BeautifulSoup
import csv

# Path to the HTML file you uploaded
file_path = '/content/papadosio_bandcamp_music.html'

# The output CSV file path
output_csv = 'papadosio_albums.csv'

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the 'ol' tag with id 'music-grid'
music_grid = soup.find('ol', id='music-grid')

# Open a CSV file to write the data
with open(output_csv, mode='w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['Album Name', 'Album Link'])  # Writing the header row

    # Iterate through each 'li' in the 'ol' tag
    for li in music_grid.find_all('li'):
        # Find the 'a' tag and extract the 'href' attribute
        a_tag = li.find('a')
        if a_tag:
            album_link = a_tag['href']
            # Check if the link needs to be converted to a full URL
            if album_link.startswith('/album'):
                album_link = BASE_URL + album_link
        else:
            album_link = 'No link'

        # Find the 'p' tag, extract the text, and trim spaces and newlines
        p_tag = li.find('p')
        album_name = p_tag.get_text().strip() if p_tag else 'No name'

        # Write the album name and link to the CSV file
        writer.writerow([album_name, album_link])

print(f'Album data has been written to {output_csv}')
# Out:
# Album data has been written to papadosio_albums.csv

# %% [markdown]
# ## Generate JSON of each album's contents

# %%
import csv
import json
import requests
from bs4 import BeautifulSoup

# The CSV file path - Adjust as needed
csv_file_path = '/content/papadosio_albums.csv'
# The output JSON file path - Adjust as needed
output_json_path = 'papadosio_albums_tracks.json'

# Function to download HTML and parse tracks
def parse_album_tracks(album_url):
    response = requests.get(album_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        tracks = []
        for td in soup.find_all('td', class_='title-col'):
            track_info = {}
            title_span = td.find('span', class_='track-title')
            if title_span:
                track_info['title'] = title_span.text.strip()
            time_span = td.find('span', class_='time')
            if time_span:
                track_info['duration'] = time_span.text.strip()
            a_tag = td.find('a')
            if a_tag:
                # Check if URL is fully resolved, if not prepend base_url
                track_url = a_tag['href']
                if not track_url.startswith('http'):
                    track_url = BASE_URL + track_url
                track_info['url'] = track_url
            tracks.append(track_info)
        return tracks
    else:
        print(f'Failed to download album page: {album_url}')
    return []

# Read the CSV file and process each album
albums_list = []
with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    for index, row in enumerate(reader, start=1):
        print(f'Processing album {index}...')
        album_data = {
            'album_name': row['Album Name'],
            'album_link': row['Album Link'],
            'tracks': parse_album_tracks(row['Album Link'])
        }
        albums_list.append(album_data)

# Write the JSON output
with open(output_json_path, 'w', encoding='utf-8') as json_file:
    json.dump(albums_list, json_file, ensure_ascii=False, indent=4)

print(f'Data has been written to {output_json_path}')
# Out:
# Processing album 1...
# Processing album 2...
# Processing album 3...
# Processing album 4...
# Processing album 5...
# Processing album 6...
# Processing album 7...
# Processing album 8...
# Processing album 9...
# Processing album 10...
# Processing album 11...
# Processing album 12...
# Processing album 13...
# Processing album 14...
# Processing album 15...
# Processing album 16...
# Processing album 17...
# Processing album 18...
# Processing album 19...
# Processing album 20...
# Processing album 21...
# Processing album 22...
# Processing album 23...
# Processing album 24...
# Processing album 25...
# Processing album 26...
# Processing album 27...
# Processing album 28...
# Processing album 29...
# Processing album 30...
# Processing album 31...
# Processing album 32...
# Processing album 33...
# Processing album 34...
# Processing album 35...
# Processing album 36...
# Processing album 37...
# Processing album 38...
# Processing album 39...
# Processing album 40...
# Processing album 41...
# Processing album 42...
# Processing album 43...
# Processing album 44...
# Processing album 45...
# Processing album 46...
# Processing album 47...
# Processing album 48...
# Processing album 49...
# Processing album 50...
# Processing album 51...
# Processing album 52...
# Processing album 53...
# Processing album 54...
# Processing album 55...
# Processing album 56...
# Processing album 57...
# Processing album 58...
# Processing album 59...
# Processing album 60...
# Processing album 61...
# Processing album 62...
# Processing album 63...
# Processing album 64...
# Processing album 65...
# Processing album 66...
# Processing album 67...
# Processing album 68...
# Processing album 69...
# Processing album 70...
# Processing album 71...
# Processing album 72...
# Processing album 73...
# Processing album 74...
# Processing album 75...
# Processing album 76...
# Processing album 77...
# Processing album 78...
# Processing album 79...
# Processing album 80...
# Processing album 81...
# Processing album 82...
# Processing album 83...
# Processing album 84...
# Processing album 85...
# Processing album 86...
# Processing album 87...
# Processing album 88...
# Processing album 89...
# Processing album 90...
# Processing album 91...
# Processing album 92...
# Processing album 93...
# Processing album 94...
# Processing album 95...
# Processing album 96...
# Processing album 97...
# Processing album 98...
# Processing album 99...
# Processing album 100...
# Processing album 101...
# Processing album 102...
# Processing album 103...
# Processing album 104...
# Processing album 105...
# Processing album 106...
# Processing album 107...
# Processing album 108...
# Processing album 109...
# Processing album 110...
# Processing album 111...
# Processing album 112...
# Processing album 113...
# Processing album 114...
# Processing album 115...
# Processing album 116...
# Processing album 117...
# Processing album 118...
# Processing album 119...
# Processing album 120...
# Processing album 121...
# Processing album 122...
# Processing album 123...
# Processing album 124...
# Processing album 125...
# Processing album 126...
# Processing album 127...
# Processing album 128...
# Processing album 129...
# Processing album 130...
# Processing album 131...
# Processing album 132...
# Processing album 133...
# Processing album 134...
# Processing album 135...
# Processing album 136...
# Processing album 137...
# Processing album 138...
# Processing album 139...
# Processing album 140...
# Processing album 141...
# Processing album 142...
# Processing album 143...
# Processing album 144...
# Processing album 145...
# Processing album 146...
# Processing album 147...
# Processing album 148...
# Processing album 149...
# Processing album 150...
# Processing album 479...
# Processing album 480...
# Processing album 481...
# Processing album 482...
# Processing album 483...
# Processing album 484...
# Processing album 485...
# Processing album 486...
# Processing album 487...
# Processing album 488...
# Processing album 489...
# Processing album 490...
# Processing album 491...
# Processing album 492...
# Processing album 493...
# Processing album 494...
# Processing album 495...
# Processing album 496...
# Processing album 497...
# Processing album 498...
# Processing album 499...
# Processing album 500...
# Processing album 501...
# Processing album 502...
# Processing album 503...
# Processing album 504...
# Processing album 505...
# Processing album 506...
# Processing album 507...
# Processing album 508...
# Processing album 509...
# Processing album 510...
# Processing album 511...
# Processing album 512...
# Processing album 513...
# Processing album 514...
# Processing album 515...
# Processing album 516...
# Processing album 517...
# Processing album 518...
# Processing album 519...
# Processing album 520...
# Processing album 521...
# Processing album 522...
# Processing album 523...
# Processing album 524...
# Processing album 525...
# Processing album 526...
# Processing album 527...
# Processing album 528...
# Processing album 529...
# Processing album 530...
# Processing album 531...
# Processing album 532...
# Processing album 533...
# Processing album 534...
# Processing album 535...
# Processing album 536...
# Processing album 537...
# Processing album 538...
# Processing album 539...
# Processing album 540...
# Processing album 541...
# Processing album 542...
# Processing album 543...
# Processing album 544...
# Processing album 545...
# Processing album 546...
# Processing album 547...
# Processing album 548...
# Processing album 549...
# Processing album 550...
# Processing album 551...
# Processing album 552...
# Processing album 553...
# Processing album 554...
# Processing album 555...
# Processing album 556...
# Processing album 557...
# Processing album 558...
# Processing album 559...
# Processing album 560...
# Processing album 561...
# Processing album 562...
# Processing album 563...
# Processing album 564...
# Processing album 565...
# Processing album 566...
# Processing album 567...
# Processing album 568...
# Processing album 569...
# Processing album 570...
# Processing album 571...
# Processing album 572...
# Processing album 573...
# Processing album 574...
# Processing album 575...
# Processing album 576...
# Processing album 577...
# Processing album 578...
# Processing album 579...
# Processing album 580...
# Processing album 581...
# Processing album 582...
# Processing album 583...
# Processing album 584...
# Processing album 585...
# Processing album 586...
# Processing album 587...
# Processing album 588...
# Processing album 589...
# Processing album 590...
# Processing album 591...
# Processing album 592...
# Processing album 593...
# Processing album 594...
# Processing album 595...
# Processing album 596...
# Processing album 597...
# Processing album 598...
# Data has been written to papadosio_albums_tracks.json

# %% [markdown]
# ## Create a list of all track names

# %%
import json

# The path to the JSON file
json_file_path = '/content/papadosio_albums_tracks.json'
# The output file for track names
output_file_path = 'sorted_unique_track_names.txt'

# Read the JSON file
with open(json_file_path, 'r', encoding='utf-8') as json_file:
    albums_data = json.load(json_file)

# Extract and process track names, ensuring uniqueness
track_names = set()
for album in albums_data:
    for track in album['tracks']:
        track_name = track['title'].strip().lower()  # Strip and make case-insensitive
        track_names.add(track_name)

# Sort the track names alphabetically
sorted_track_names = sorted(track_names)

# Write the sorted, unique track names to a new file
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for track_name in sorted_track_names:
        output_file.write(f'{track_name}\n')

print(f'Sorted, unique track names have been written to {output_file_path}')
# Out:
# Sorted, unique track names have been written to sorted_unique_track_names.txt
